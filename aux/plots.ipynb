# %%
# Import plotting functions
import numpy as np
import matplotlib.pyplot as plt
import getdist.plots as gdplt
from getdist import loadMCSamples

# path info
import os
print(os.getcwd())
# Out:
# /Users/genebelinario/Desktop/ccg_project

# %%
# values
burn_in = 0.3

# %%
# chain prefix
chain0 = 'chains/CMB-SPA/CMB-SPA'      # CMB-SPA
chain1 = 'chains/PPS+DESI/PPS+DESI'    # PPS + DESI 
chain2 = 'chains/PP+DESI/PP+DESI'      # PP + DESI
chain3 = 'chains/CMB-SPA+PPS+DESI'     # CMB-SPA + PPS + DESI
chain4 = 'chains/CMB-SPA+PP+DESI'      # CMB-SPA + PP + DESI

# load samples
#samples0 = loadMCSamples(chain0, settings={'ignore_rows':burn_in})
samples1 = loadMCSamples(chain1, settings={'ignore_rows':burn_in})
samples2 = loadMCSamples(chain2, settings={'ignore_rows':burn_in})
#samples3 = loadMCSamples(chain3, settings={'ignore_rows':burn_in})
#samples4 = loadMCSamples(chain4, settings={'ignore_rows':burn_in})

# show stats
#stats0 = samples0.getMargeStats()
#stats1 = samples1.getMargeStats()
#stats2 = samples2.getMargeStats()
#stats3 = samples3.getMargeStats()
#stats4 = samples4.getMargeStats()

# print stats
#print(stats1.parWithName('H0').mean)
# Out:
# WARNING:root:auto bandwidth for logA very small or failed (h=0.0006740063345101209,N_eff=23121.16633051358). Using fallback (h=0.053923873058328735)
# WARNING:root:auto bandwidth for ns very small or failed (h=0.0006719690850672262,N_eff=23128.681743573696). Using fallback (h=0.053664456846607665)
# WARNING:root:auto bandwidth for YHe very small or failed (h=0.00028903369005546113,N_eff=3278.3928938037684). Using fallback (h=0.03261996376762861)
# WARNING:root:auto bandwidth for Y_p very small or failed (h=0.00028904549993039996,N_eff=3278.391614697816). Using fallback (h=0.03262016932768437)
# WARNING:root:auto bandwidth for DHBBN very small or failed (h=0.0002884957058255153,N_eff=3265.2727448549167). Using fallback (h=0.03336144578242235)
# WARNING:root:auto bandwidth for logA very small or failed (h=0.0007307654154128265,N_eff=83998.63315190363). Using fallback (h=0.041745661428788466)
# WARNING:root:auto bandwidth for ns very small or failed (h=0.0006858948157809931,N_eff=84004.56633084673). Using fallback (h=0.04148214764604925)
# WARNING:root:auto bandwidth for YHe very small or failed (h=8.432123731910803e-05,N_eff=7605.784524487655). Using fallback (h=0.0)
# WARNING:root:fine_bins not large enough to well sample smoothing scale - YHe
# WARNING:root:auto bandwidth for Y_p very small or failed (h=8.432076352727262e-05,N_eff=7605.871451291627). Using fallback (h=0.0)
# WARNING:root:fine_bins not large enough to well sample smoothing scale - Y_p
# WARNING:root:auto bandwidth for DHBBN very small or failed (h=8.16865045556774e-05,N_eff=8879.998103688398). Using fallback (h=0.0)
# WARNING:root:fine_bins not large enough to well sample smoothing scale - DHBBN
# 73.4090424434052
